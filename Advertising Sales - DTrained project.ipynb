# %% [markdown]
# # Advertising Sales Channel Prediction

# %% [markdown]
# Problem Statement:

# %% [markdown]
# Sales Channel Prediction Case Study
#
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.

# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.sample()
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 68          69  237.4   27.5       11.0   18.9

# %%
df.sample(5)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 165         166  234.5    3.4       84.8   11.9
# 116         117  139.2   14.3       25.6   12.2
# 109         110  255.4   26.9        5.5   19.8
# 197         198  177.0    9.3        6.4   12.8
# 55           56  198.9   49.4       60.0   23.7

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.describe(include='all')
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
corr_mat=df.corr()
#size of the canvas
plt.figure(figsize=[80,80])
#plot the correlation matrix
sns.heatmap(corr_mat,annot=True)
plt.title('Correlation Matrix')
plt.savefig('correlation_matrix.jpg')
plt.show()

# %% [markdown]
# there are very weak correlation between unknown column and newspaper , unknown and radio

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
type(corr_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matr=df.corr()
corr_matrix['sales'].sort_values(ascending=False)
# Out:
# sales         1.000000
# TV            0.782224
# radio         0.576223
# newspaper     0.228299
# Unnamed: 0   -0.051616
# Name: sales, dtype: float64

# %% [markdown]
# Let's check the data distribution among all the columns

# %%
df.plot(kind='density',subplots=True,layout=(6,5),sharex=False,legend=False,fontsize=1,figsize=(18,12))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
# ...

# %% [markdown]
# Splitting the independent the dependent variable for skewness

# %%
x=df.drop(['sales','Unnamed: 0'],axis=1)
y=df['sales']

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# 30   292.9   28.3       43.2
# ...

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
# 30     21.4
# 31     11.9
# 32      9.6
# 33     17.4
# 34      9.5
# 35     12.8
# 36     25.4
# 37     14.7
# 38     10.1
# 39     21.5
# 40     16.6
# 41     17.1
# 42     20.7
# 43     12.9
# 44      8.5
# 45     14.9
# 46     10.6
# 47     23.2
# 48     14.8
# 49      9.7
# 50     11.4
# 51     10.7
# 52     22.6
# 53     21.2
# 54     20.2
# 55     23.7
# 56      5.5
# 57     13.2
# 58     23.8
# 59     18.4
# 60      8.1
# 61     24.2
# 62     15.7
# 63     14.0
# 64     18.0
# 65      9.3
# 66      9.5
# 67     13.4
# 68     18.9
# 69     22.3
# 70     18.3
# ...

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
x.skew().sort_values(ascending=False)
# Out:
# newspaper    0.894720
# radio        0.094175
# TV          -0.069853
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
pd.DataFrame(x_new).skew().sort_values(ascending=False)
# Out:
# 2   -0.077942
# 1   -0.242968
# 0   -0.315199
# dtype: float64

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['TV', 'radio', 'newspaper'], dtype='object')

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#            TV     radio  newspaper
# 0    0.948674  0.962247   1.514335
# 1   -1.191314  1.040179   0.787683
# 2   -1.647757  1.370710   1.516998
# 3    0.141020  1.142387   1.214656
# 4    0.452715 -0.748651   1.211704
# 5   -1.823822  1.515019   1.665024
# 6   -1.002491  0.693727  -0.107753
# 7   -0.210275 -0.101585  -0.844093
# 8   -1.826095 -1.633454  -2.132597
# 9    0.647645 -1.566770  -0.229004
# 10  -0.883774 -1.202988  -0.072262
# 11   0.797084  0.180726  -1.602619
# 12  -1.526416  0.819006   1.425129
# 13  -0.480368 -1.028136  -1.229825
# 14   0.691066  0.699240   0.818606
# 15   0.602957  1.457704   1.044323
# 16  -0.860800  0.899070   2.529435
# 17   1.435520  1.055631   1.133833
# 18  -0.841993 -0.042099  -0.393560
# 19   0.095086  0.174532  -0.346715
# 20   0.833761  0.403671   1.059965
# 21   1.019586 -1.275673  -0.107753
# 22  -1.727016 -0.357393   0.938757
# 23   0.931098 -0.286311   0.025893
# 24  -0.935698 -0.604311  -0.393560
# 25   1.262909 -1.455058  -0.323726
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# newspaper   -0.077942
# radio       -0.242968
# TV          -0.315199
# dtype: float64

# %%
sk=x.skew()

# %%
sk
# Out:
# TV          -0.315199
# radio       -0.242968
# newspaper   -0.077942
# dtype: float64

# %%
sk[np.abs(sk)>0.5].all()
# Out:
# True

# %%
sk[np.abs(sk)<0.5]
# Out:
# TV          -0.315199
# radio       -0.242968
# newspaper   -0.077942
# dtype: float64

# %%
x.skew()[np.abs(x.skew())<0.25].all()
# Out:
# True

# %% [markdown]
# Skewness has been removed now we can proceed with further steps

# %% [markdown]
# # Checking Outliers

# %%
# Plotting boxplots 
x.iloc[:,0:4].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# There is no outliers are presented in my dataset

# %% [markdown]
# # Visualization

# %% [markdown]
# Distribution plot

# %%
sns.distplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# Boxplot

# %%
df['TV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['radio'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['newspaper'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Regression plot

# %%
sns.regplot(x='TV',y='sales',data=df)
plt.ylim(0.0001,)
plt.xlim(0.0001,)
# Out:
# (0.0001, 311.185)

# %%
sns.regplot(x='radio',y='sales',data=df)
plt.ylim(0.1,)
plt.xlim(0.1,)
# Out:
# (0.1, 52.08)

# %%
sns.regplot(x='newspaper',y='sales',data=df)
plt.ylim(.01,)
plt.xlim(0.1,)
# Out:
# (0.1, 119.685)

# %% [markdown]
# All independent variables are showing positive linear relationship to dependent variables

# %% [markdown]
# Scatter plots

# %%
plt.scatter(df['TV'],df['sales'])
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(df['radio'],df['sales'])
plt.xlabel('radio')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(df['newspaper'],df['sales'])
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()

# %%
df.hist(grid=False,figsize=(10,6),bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'TV'}>],
#        [<AxesSubplot:title={'center':'radio'}>,
#         <AxesSubplot:title={'center':'newspaper'}>],
#        [<AxesSubplot:title={'center':'sales'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.pairplot(df)

# %% [markdown]
# # Training process begin

# %% [markdown]
# Creating the train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
x_train
# Out:
#            TV     radio  newspaper
# 108 -1.729069 -1.900767  -0.003069
# 107 -0.568145 -1.919627  -0.123157
# 189 -1.619272 -0.643632  -0.112875
# 14   0.691066  0.699240   0.818606
# 56  -1.856247  0.427096   0.656460
# 19   0.095086  0.174532  -0.346715
# 114 -0.723372  1.414363   0.391339
# 39   0.928165  0.957011   0.287423
# 185  0.700123  1.331638  -0.318022
# 124  0.942820  0.666067   1.644673
# 98   1.511976  1.192798   0.990457
# 123 -0.176788  0.792037  -0.783475
# 119 -1.606178 -0.350214  -0.170089
# 53   0.471407  1.385296   1.220552
# 33   1.288297 -0.075027  -2.324725
# 179  0.292838 -0.815479  -0.435547
# 181  0.834750 -1.244152   0.082652
# 106 -1.505340 -0.732217   0.187417
# 199  0.968161 -0.937083  -1.086425
# 138 -1.213971  0.296676  -0.267443
# 116  0.005504 -0.474562  -0.003069
# 67   0.006618 -0.459668  -0.956199
# 78  -1.902720  0.531023  -1.024206
# 42   1.547700  0.403671  -1.959049
# 17   1.435520  1.055631   1.133833
# 5   -1.823822  1.515019   1.665024
# ...

# %%
x_test
# Out:
#            TV     radio  newspaper
# 58   0.758242  1.548209   0.517932
# 40   0.674938  0.074096   0.270349
# 34  -0.502457 -1.734211  -1.209813
# 102  1.424417 -0.807026  -0.218160
# 184  1.176827  0.009984   0.200719
# 198  1.455843  1.177722   1.433350
# 95   0.268314  0.627074   1.044323
# 4    0.452715 -0.748651   1.211704
# 29  -0.823286 -0.350214   0.634520
# 168  0.804035  0.155892   1.187973
# 171  0.281121 -0.015967   0.865987
# 18  -0.841993 -0.042099  -0.393560
# 11   0.797084  0.180726  -1.602619
# 89  -0.332176  1.462500   0.996851
# 110  0.906625 -0.973048   1.155012
# 118 -0.146942  0.914935   1.769743
# 159 -0.078680 -0.182468   0.395400
# 35   1.521148 -1.385313  -1.104711
# 136 -1.494899  1.024682  -1.032932
# 59   0.757244  0.508132  -1.032932
# 51  -0.445005 -0.849587  -1.658836
# 16  -0.860800  0.899070   2.529435
# 44  -1.503595  0.284621   0.724694
# 94  -0.360733 -0.497042  -0.899124
# 31  -0.295533 -0.251340   0.552359
# 162  0.531309 -0.202984  -0.003069
# ...

# %%
y_train
# Out:
# 108     5.3
# 107     8.7
# 189     6.7
# 14     19.0
# 56      5.5
# 19     14.6
# 114    14.6
# 39     21.5
# 185    22.6
# 124    19.7
# 98     25.4
# 123    15.2
# 119     6.6
# 53     21.2
# 33     17.4
# 179    12.6
# 181    12.2
# 106     7.2
# 199    13.4
# 138     9.6
# 116    12.2
# 67     13.4
# 78      5.3
# 42     20.7
# 17     24.4
# 5       7.2
# 127     8.8
# 105    19.2
# 48     14.8
# 66      9.5
# 54     20.2
# 84     21.7
# 183    26.2
# 158     7.3
# 166     8.0
# 113    15.9
# 12      9.2
# 117     9.4
# 93     22.2
# 120    15.5
# 154    15.6
# 90     11.2
# 81     12.3
# 122    11.6
# 191     9.9
# 13      9.7
# 82     11.3
# 132     5.7
# 187    17.3
# 45     14.9
# 99     17.2
# 36     25.4
# 161    13.3
# 186    10.3
# 153    19.0
# 103    14.7
# 195     7.6
# 197    12.8
# 148    10.9
# 173    11.7
# 75      8.7
# 21     12.5
# 91      7.3
# 152    16.6
# 2       9.3
# 70     18.3
# 85     15.2
# 150    16.1
# 6      11.8
# 112    14.1
# 0      22.1
# ...

# %%
y_test
# Out:
# 58     23.8
# 40     16.6
# 34      9.5
# 102    14.8
# 184    17.6
# 198    25.5
# 95     16.9
# 4      12.9
# 29     10.5
# 168    17.1
# 171    14.5
# 18     11.3
# 11     17.4
# 89     16.7
# 110    13.4
# 118    15.9
# 159    12.9
# 35     12.8
# 136     9.5
# 59     18.4
# 51     10.7
# 16     12.5
# 44      8.5
# 94     11.5
# 31     11.9
# 162    14.9
# 38     10.1
# 28     18.9
# 193    19.6
# 27     15.9
# 47     23.2
# 165    11.9
# 194    17.3
# 177    11.7
# 176    20.2
# 97     15.5
# 174    11.5
# 73     11.0
# 69     22.3
# 172     7.6
# Name: sales, dtype: float64

# %%
x_train.shape
# Out:
# (160, 3)

# %%
y_train.shape
# Out:
# (160,)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
y_test.shape
# Out:
# (40,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
coeff_df=pd.DataFrame(lr.coef_,x.columns,columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
# TV            4.042094
# radio         2.610056
# newspaper     0.161451

# %%
lr.intercept_
# Out:
# 14.071555626900055

# %% [markdown]
# TO make predictions on the test data

# %%
y_pred=lr.predict(x_test)

# %%
comp_df=pd.DataFrame({'Actual Sales':y_test,'Predicted Sales':y_pred})
comp_df
# Out:
#      Actual Sales  Predicted Sales
# 58           23.8        21.260975
# 40           16.6        17.036760
# 34            9.5         7.318862
# 102          14.8        17.687577
# 184          17.6        18.886868
# 198          25.5        23.261546
# 95           16.9        16.961414
# 4            12.9        14.143082
# 29           10.5         9.932120
# 168          17.1        17.920228
# 171          14.5        15.306012
# 18           11.3        10.494718
# 11           17.4        17.506403
# 89           16.7        16.707018
# 110          13.4        15.382987
# 118          15.9        16.151364
# 159          12.9        13.341111
# 35           12.8        16.426079
# 136           9.5        10.536742
# 59           18.4        18.291892
# 51           10.7         9.787512
# 16           12.5        13.347125
# 44            8.5         8.853761
# 94           11.5        11.170967
# 31           11.9        12.310148
# 162          14.9        15.688859
# ...

# %%
comp_df.shape
# Out:
# (40, 2)

# %%
print('Errors:')
print('Mean Squared Error :',mean_squared_error(y_test,y_pred))
print('Mean Absolute Error :',mean_absolute_error(y_test,y_pred))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Errors:
# Mean Squared Error : 1.9275861495665083
# Mean Absolute Error : 1.0653395142698652
# Root Mean Squared Error : 1.3883753633533362

# %% [markdown]
# # To find coefficient of determination - r2 score

# %%
from sklearn.metrics import r2_score
print('Coefficient of determination :',r2_score(y_test,y_pred))
# Out:
# Coefficient of determination : 0.8962223515318661

# %%
lr.score(x_test,y_test).round(3)
# Out:
# 0.896

# %% [markdown]
# Our coefficient of determination is greater than 0.7, so our model is not bad. Also our model is some
# what close to 1. Now let's see the score of the model on the training data

# %%
lr.score(x_train,y_train).round(3)
# Out:
# 0.907

# %% [markdown]
# We can see the performance of the model on the training data is close to the performance of the test
# data. Therefore our model is not overfitted
